# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torchvision
from torchvision.datasets import ImageFolder
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd

# %%
train_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.RandomGrayscale(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees = 90),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
])

normalize_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
])

# %%
test_path = './catdog_data/test'
train_path = './catdog_data/train'
validation_path = './catdog_data/validation'

train_data = ImageFolder(root = train_path, transform = train_transform)
test_data = ImageFolder(root = test_path, transform = normalize_transform)
validation_data = ImageFolder(root = validation_path, transform = normalize_transform)

# %%
import pickle

class CNN(nn.Module):

    def __init__(self, activation_function):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 128, kernel_size = 3, padding = 1)
        self.act1 = activation_function
        self.maxpool1 = nn.MaxPool2d(kernel_size = 2)
        self.conv2 = nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = 3, padding = 1)
        self.act2 = activation_function
        self.maxpool2 = nn.MaxPool2d(kernel_size = 2)
        self.conv3 = nn.Conv2d(in_channels = 64, out_channels = 32, kernel_size = 3, padding = 1)
        self.act3 = activation_function
        self.maxpool3 = nn.MaxPool2d(kernel_size = 2)
        self.conv4 = nn.Conv2d(in_channels = 32, out_channels = 2, kernel_size = 3, padding = 1)
        self.act4 = activation_function
        self.maxpool4 = nn.MaxPool2d(kernel_size = 2)

        self.dropout = nn.Dropout(0.2)
        self.fc1 = nn.Linear(2 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.act5 = activation_function
    
    def forward(self, x):
        x = self.act1(self.conv1(x))
        x = self.maxpool1(x)
        x = self.act2(self.conv2(x))
        x = self.maxpool2(x)
        x = self.act3(self.conv3(x))
        x = self.maxpool3(x)
        x = self.act4(self.conv4(x))
        x = self.maxpool4(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.act5(self.fc1(x))
        x = self.fc2(x)
        return x

def train(network, data_loader, criterion, optimizer, device):
    network.train()
    running_loss = 0.0
    for data, target in data_loader:
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = network(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * data.size(0)
    
    return running_loss / len(data_loader.dataset)

def validation(network, data_loader, criterion, device):
    network.eval()
    correct = 0
    total = 0
    val_loss = 0.0

    with torch.no_grad():
        for data, target in data_loader:
            data, target = data.to(device), target.to(device)

            output = network(data)
            loss = criterion(output, target)
            val_loss += loss.item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
    
    return val_loss / len(data_loader.dataset), 100 * correct / total

results = []

batch_sizes = [128, 128, 256, 64, 64, 128, 256, 64, 128]
learning_rate = 0.001

activation_functions = {
    'ReLU - 128': nn.ReLU(),
    'Tanh - 128': nn.Tanh(),
    'Tanh - 256': nn.Tanh(),
    'LeakyReLU - 64': nn.LeakyReLU(),
    'ELU - 64': nn.ELU(),
    'ELU - 128': nn.ELU(),
    'ELU - 256': nn.ELU(),
    'SiLU - 64': nn.SiLU(),
    'SiLU - 128': nn.SiLU()
}

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 50

indices_to_test = [0, 1, 2, 3, 4, 5, 6, 7, 8]

for idx in range(0, len(batch_sizes)):
    act_name = list(activation_functions.keys())[idx]
    activation_function = list(activation_functions.values())[idx]
    batch_size = batch_sizes[idx]

    print(f"\n=== Testing {act_name} with batch size {batch_size} ===")

    activation_results = []

    train_dataloader = DataLoader(
        dataset = train_data,
        batch_size = batch_size,
        shuffle = True,
        num_workers = 2
    )

    validation_dataloader = DataLoader(
        dataset = validation_data,
        batch_size = batch_size,
        shuffle = False,
        num_workers = 2
    )

    test_dataloader = DataLoader(
        dataset = test_data,
        batch_size = batch_size,
        shuffle = False,
        num_workers = 2
    )

    model = CNN(activation_function).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr = learning_rate)

    train_loss_history = []
    val_loss_history = []
    val_accuracy_history = []

    for epoch in range(num_epochs):
        train_loss = train(model, train_dataloader, criterion, optimizer, device)
        val_loss, val_accuracy = validation(model, validation_dataloader, criterion, device)

        train_loss_history.append(train_loss)
        val_loss_history.append(val_loss)
        val_accuracy_history.append(val_accuracy)

        print(f"Epoch [{epoch + 1}/{num_epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f} %")

    results.append({
        "index": idx,
        "batch_size": batch_size,
        "learning_rate": learning_rate,
        "activation_function": act_name,
        "optimizer": "Adam",
        "train_loss_history": train_loss_history,
        "val_loss_history": val_loss_history,
        "val_accuracy_history": val_accuracy_history
    })

    activation_results.append({
        "batch_size": batch_size,
        "learning_rate": learning_rate,
        "optimizer": "Adam",
        "train_loss_history": train_loss_history,
        "val_loss_history": val_loss_history,
        "val_accuracy_history": val_accuracy_history
    })

    with open(f"select_cnn_experiments_{act_name}_{batch_size}.pkl", "wb") as f:
        pickle.dump(activation_results, f)
    
    print(f"\nResults saved for {act_name}-{batch_size}")

with open(f"select_cnn_experiments.pkl", "wb") as f:
    pickle.dump(results, f)

print("\nAll results saved")
# Out:
# === Testing ReLU - 128 with batch size 128 ===
# Epoch [1/50], Validation Loss: 0.6924, Validation Accuracy: 53.67 %
# Epoch [2/50], Validation Loss: 0.6917, Validation Accuracy: 53.83 %
# Epoch [3/50], Validation Loss: 0.6904, Validation Accuracy: 53.67 %
# Epoch [4/50], Validation Loss: 0.6878, Validation Accuracy: 55.67 %
# Epoch [5/50], Validation Loss: 0.6886, Validation Accuracy: 51.17 %
# Epoch [6/50], Validation Loss: 0.6870, Validation Accuracy: 55.83 %
# Epoch [7/50], Validation Loss: 0.6843, Validation Accuracy: 56.33 %
# Epoch [8/50], Validation Loss: 0.6822, Validation Accuracy: 59.00 %
# Epoch [9/50], Validation Loss: 0.6761, Validation Accuracy: 59.50 %
# Epoch [10/50], Validation Loss: 0.6683, Validation Accuracy: 60.00 %
# Epoch [11/50], Validation Loss: 0.6863, Validation Accuracy: 55.33 %
# Epoch [12/50], Validation Loss: 0.6682, Validation Accuracy: 59.00 %
# Epoch [13/50], Validation Loss: 0.6556, Validation Accuracy: 62.17 %
# Epoch [14/50], Validation Loss: 0.6468, Validation Accuracy: 62.83 %
# Epoch [15/50], Validation Loss: 0.6398, Validation Accuracy: 63.00 %
# Epoch [16/50], Validation Loss: 0.6444, Validation Accuracy: 65.50 %
# Epoch [17/50], Validation Loss: 0.6308, Validation Accuracy: 65.00 %
# Epoch [18/50], Validation Loss: 0.6249, Validation Accuracy: 65.33 %
# Epoch [19/50], Validation Loss: 0.6334, Validation Accuracy: 66.17 %
# Epoch [20/50], Validation Loss: 0.6285, Validation Accuracy: 66.50 %
# Epoch [21/50], Validation Loss: 0.6306, Validation Accuracy: 65.83 %
# Epoch [22/50], Validation Loss: 0.6309, Validation Accuracy: 65.33 %
# Epoch [23/50], Validation Loss: 0.6632, Validation Accuracy: 65.50 %
# Epoch [24/50], Validation Loss: 0.6256, Validation Accuracy: 67.50 %
# Epoch [25/50], Validation Loss: 0.6334, Validation Accuracy: 66.83 %
# Epoch [26/50], Validation Loss: 0.6427, Validation Accuracy: 65.67 %
# Epoch [27/50], Validation Loss: 0.6180, Validation Accuracy: 66.67 %
# Epoch [28/50], Validation Loss: 0.6261, Validation Accuracy: 68.17 %
# Epoch [29/50], Validation Loss: 0.6348, Validation Accuracy: 64.67 %
# Epoch [30/50], Validation Loss: 0.6275, Validation Accuracy: 67.00 %
# Epoch [31/50], Validation Loss: 0.6173, Validation Accuracy: 70.00 %
# Epoch [32/50], Validation Loss: 0.6315, Validation Accuracy: 66.00 %
# Epoch [33/50], Validation Loss: 0.6255, Validation Accuracy: 70.00 %
# Epoch [34/50], Validation Loss: 0.6110, Validation Accuracy: 66.00 %
# Epoch [35/50], Validation Loss: 0.6076, Validation Accuracy: 69.83 %
# Epoch [36/50], Validation Loss: 0.6378, Validation Accuracy: 66.00 %
# Epoch [37/50], Validation Loss: 0.6109, Validation Accuracy: 68.83 %
# Epoch [38/50], Validation Loss: 0.6237, Validation Accuracy: 66.50 %
# Epoch [39/50], Validation Loss: 0.6048, Validation Accuracy: 70.33 %
# Epoch [40/50], Validation Loss: 0.5980, Validation Accuracy: 69.83 %
# Epoch [41/50], Validation Loss: 0.6007, Validation Accuracy: 71.17 %
# Epoch [42/50], Validation Loss: 0.6087, Validation Accuracy: 68.83 %
# Epoch [43/50], Validation Loss: 0.5952, Validation Accuracy: 69.83 %
# Epoch [44/50], Validation Loss: 0.5930, Validation Accuracy: 71.17 %
# Epoch [45/50], Validation Loss: 0.5940, Validation Accuracy: 70.00 %
# Epoch [46/50], Validation Loss: 0.6013, Validation Accuracy: 68.50 %
# Epoch [47/50], Validation Loss: 0.6119, Validation Accuracy: 67.17 %
# Epoch [48/50], Validation Loss: 0.6215, Validation Accuracy: 66.83 %
# Epoch [49/50], Validation Loss: 0.5916, Validation Accuracy: 70.50 %
# Epoch [50/50], Validation Loss: 0.5982, Validation Accuracy: 69.67 %
#
# Results saved for ReLU - 128-128
#
# === Testing Tanh - 128 with batch size 128 ===
# Epoch [1/50], Validation Loss: 0.6935, Validation Accuracy: 50.83 %
# Epoch [2/50], Validation Loss: 0.7043, Validation Accuracy: 51.67 %
# Epoch [3/50], Validation Loss: 0.6922, Validation Accuracy: 51.83 %
# Epoch [4/50], Validation Loss: 0.6858, Validation Accuracy: 54.67 %
# Epoch [5/50], Validation Loss: 0.6833, Validation Accuracy: 55.83 %
# Epoch [6/50], Validation Loss: 0.6728, Validation Accuracy: 57.50 %
# Epoch [7/50], Validation Loss: 0.6816, Validation Accuracy: 55.50 %
# Epoch [8/50], Validation Loss: 0.6693, Validation Accuracy: 58.33 %
# Epoch [9/50], Validation Loss: 0.6410, Validation Accuracy: 62.83 %
# Epoch [10/50], Validation Loss: 0.6511, Validation Accuracy: 62.33 %
# Epoch [11/50], Validation Loss: 0.6688, Validation Accuracy: 59.00 %
# Epoch [12/50], Validation Loss: 0.6366, Validation Accuracy: 64.83 %
# Epoch [13/50], Validation Loss: 0.6325, Validation Accuracy: 67.33 %
# Epoch [14/50], Validation Loss: 0.6445, Validation Accuracy: 64.50 %
# Epoch [15/50], Validation Loss: 0.6380, Validation Accuracy: 64.00 %
# Epoch [16/50], Validation Loss: 0.6332, Validation Accuracy: 64.83 %
# Epoch [17/50], Validation Loss: 0.6143, Validation Accuracy: 66.67 %
# Epoch [18/50], Validation Loss: 0.6291, Validation Accuracy: 64.17 %
# Epoch [19/50], Validation Loss: 0.6153, Validation Accuracy: 66.33 %
# Epoch [20/50], Validation Loss: 0.6150, Validation Accuracy: 66.67 %
# Epoch [21/50], Validation Loss: 0.6315, Validation Accuracy: 64.00 %
# Epoch [22/50], Validation Loss: 0.6205, Validation Accuracy: 67.33 %
# Epoch [23/50], Validation Loss: 0.6154, Validation Accuracy: 66.00 %
# Epoch [24/50], Validation Loss: 0.6056, Validation Accuracy: 67.33 %
# Epoch [25/50], Validation Loss: 0.6063, Validation Accuracy: 68.67 %
# Epoch [26/50], Validation Loss: 0.6210, Validation Accuracy: 65.33 %
# Epoch [27/50], Validation Loss: 0.6063, Validation Accuracy: 68.83 %
# Epoch [28/50], Validation Loss: 0.6227, Validation Accuracy: 65.33 %
# Epoch [29/50], Validation Loss: 0.6054, Validation Accuracy: 67.83 %
# Epoch [30/50], Validation Loss: 0.6144, Validation Accuracy: 67.83 %
# Epoch [31/50], Validation Loss: 0.6203, Validation Accuracy: 67.17 %
# Epoch [32/50], Validation Loss: 0.6039, Validation Accuracy: 68.50 %
# Epoch [33/50], Validation Loss: 0.6165, Validation Accuracy: 67.17 %
# Epoch [34/50], Validation Loss: 0.6050, Validation Accuracy: 69.00 %
# Epoch [35/50], Validation Loss: 0.6117, Validation Accuracy: 66.17 %
# Epoch [36/50], Validation Loss: 0.6056, Validation Accuracy: 66.50 %
# Epoch [37/50], Validation Loss: 0.6292, Validation Accuracy: 68.50 %
# Epoch [38/50], Validation Loss: 0.6024, Validation Accuracy: 68.33 %
# Epoch [39/50], Validation Loss: 0.5995, Validation Accuracy: 68.00 %
# Epoch [40/50], Validation Loss: 0.6013, Validation Accuracy: 70.33 %
# Epoch [41/50], Validation Loss: 0.6203, Validation Accuracy: 67.00 %
# Epoch [42/50], Validation Loss: 0.5941, Validation Accuracy: 68.33 %
# Epoch [43/50], Validation Loss: 0.6193, Validation Accuracy: 67.00 %
# Epoch [44/50], Validation Loss: 0.5903, Validation Accuracy: 68.33 %
# Epoch [45/50], Validation Loss: 0.5990, Validation Accuracy: 68.83 %
# Epoch [46/50], Validation Loss: 0.6165, Validation Accuracy: 65.33 %
# Epoch [47/50], Validation Loss: 0.6133, Validation Accuracy: 67.50 %
# Epoch [48/50], Validation Loss: 0.5941, Validation Accuracy: 67.83 %
# Epoch [49/50], Validation Loss: 0.5705, Validation Accuracy: 71.33 %
# Epoch [50/50], Validation Loss: 0.5881, Validation Accuracy: 68.50 %
#
# Results saved for Tanh - 128-128
#
# === Testing Tanh - 256 with batch size 256 ===
# Epoch [1/50], Validation Loss: 0.6919, Validation Accuracy: 51.33 %
# Epoch [2/50], Validation Loss: 0.6850, Validation Accuracy: 57.17 %
# Epoch [3/50], Validation Loss: 0.6800, Validation Accuracy: 57.50 %
# Epoch [4/50], Validation Loss: 0.6678, Validation Accuracy: 58.50 %
# Epoch [5/50], Validation Loss: 0.6512, Validation Accuracy: 61.67 %
# Epoch [6/50], Validation Loss: 0.6653, Validation Accuracy: 59.67 %
# Epoch [7/50], Validation Loss: 0.6577, Validation Accuracy: 61.33 %
# Epoch [8/50], Validation Loss: 0.6689, Validation Accuracy: 59.83 %
# Epoch [9/50], Validation Loss: 0.6533, Validation Accuracy: 62.83 %
# Epoch [10/50], Validation Loss: 0.6479, Validation Accuracy: 62.33 %
# Epoch [11/50], Validation Loss: 0.6489, Validation Accuracy: 61.00 %
# Epoch [12/50], Validation Loss: 0.6470, Validation Accuracy: 63.50 %
# Epoch [13/50], Validation Loss: 0.6524, Validation Accuracy: 62.50 %
# Epoch [14/50], Validation Loss: 0.6451, Validation Accuracy: 64.00 %
# Epoch [15/50], Validation Loss: 0.6427, Validation Accuracy: 63.83 %
# Epoch [16/50], Validation Loss: 0.6431, Validation Accuracy: 62.67 %
# Epoch [17/50], Validation Loss: 0.6646, Validation Accuracy: 59.50 %
# Epoch [18/50], Validation Loss: 0.6358, Validation Accuracy: 62.83 %
# Epoch [19/50], Validation Loss: 0.6286, Validation Accuracy: 65.67 %
# Epoch [20/50], Validation Loss: 0.6388, Validation Accuracy: 62.33 %
# Epoch [21/50], Validation Loss: 0.6260, Validation Accuracy: 65.33 %
# Epoch [22/50], Validation Loss: 0.6202, Validation Accuracy: 65.17 %
# Epoch [23/50], Validation Loss: 0.6392, Validation Accuracy: 63.83 %
# Epoch [24/50], Validation Loss: 0.6360, Validation Accuracy: 62.33 %
# Epoch [25/50], Validation Loss: 0.6219, Validation Accuracy: 65.50 %
# Epoch [26/50], Validation Loss: 0.6281, Validation Accuracy: 64.67 %
# Epoch [27/50], Validation Loss: 0.6130, Validation Accuracy: 65.50 %
# Epoch [28/50], Validation Loss: 0.6127, Validation Accuracy: 65.17 %
# Epoch [29/50], Validation Loss: 0.6199, Validation Accuracy: 66.17 %
# Epoch [30/50], Validation Loss: 0.6068, Validation Accuracy: 65.33 %
# Epoch [31/50], Validation Loss: 0.6086, Validation Accuracy: 64.67 %
# Epoch [32/50], Validation Loss: 0.6301, Validation Accuracy: 63.33 %
# Epoch [33/50], Validation Loss: 0.6051, Validation Accuracy: 66.33 %
# Epoch [34/50], Validation Loss: 0.6063, Validation Accuracy: 66.50 %
# Epoch [35/50], Validation Loss: 0.6222, Validation Accuracy: 65.00 %
# Epoch [36/50], Validation Loss: 0.6081, Validation Accuracy: 66.17 %
# Epoch [37/50], Validation Loss: 0.5971, Validation Accuracy: 66.83 %
# Epoch [38/50], Validation Loss: 0.5890, Validation Accuracy: 68.83 %
# Epoch [39/50], Validation Loss: 0.5967, Validation Accuracy: 67.00 %
# Epoch [40/50], Validation Loss: 0.5908, Validation Accuracy: 67.33 %
# Epoch [41/50], Validation Loss: 0.6080, Validation Accuracy: 66.67 %
# Epoch [42/50], Validation Loss: 0.5922, Validation Accuracy: 68.50 %
# Epoch [43/50], Validation Loss: 0.6432, Validation Accuracy: 67.17 %
# Epoch [44/50], Validation Loss: 0.5951, Validation Accuracy: 69.17 %
# Epoch [45/50], Validation Loss: 0.6126, Validation Accuracy: 65.83 %
# Epoch [46/50], Validation Loss: 0.5961, Validation Accuracy: 69.50 %
# Epoch [47/50], Validation Loss: 0.5876, Validation Accuracy: 70.67 %
# Epoch [48/50], Validation Loss: 0.5819, Validation Accuracy: 68.83 %
# Epoch [49/50], Validation Loss: 0.5775, Validation Accuracy: 69.50 %
# Epoch [50/50], Validation Loss: 0.6081, Validation Accuracy: 67.00 %
#
# Results saved for Tanh - 256-256
#
# === Testing LeakyReLU - 64 with batch size 64 ===
# Epoch [1/50], Validation Loss: 0.6908, Validation Accuracy: 58.00 %
# Epoch [2/50], Validation Loss: 0.6932, Validation Accuracy: 50.00 %
# Epoch [3/50], Validation Loss: 0.6932, Validation Accuracy: 50.00 %
# Epoch [4/50], Validation Loss: 0.6932, Validation Accuracy: 50.00 %
# Epoch [5/50], Validation Loss: 0.6932, Validation Accuracy: 50.00 %
# Epoch [6/50], Validation Loss: 0.6931, Validation Accuracy: 50.00 %
# Epoch [7/50], Validation Loss: 0.6931, Validation Accuracy: 50.00 %
# Epoch [8/50], Validation Loss: 0.6931, Validation Accuracy: 50.00 %
# Epoch [9/50], Validation Loss: 0.6931, Validation Accuracy: 50.00 %
# Epoch [10/50], Validation Loss: 0.6931, Validation Accuracy: 50.00 %
# Epoch [11/50], Validation Loss: 0.6922, Validation Accuracy: 55.50 %
# Epoch [12/50], Validation Loss: 0.6912, Validation Accuracy: 51.83 %
# Epoch [13/50], Validation Loss: 0.6862, Validation Accuracy: 53.83 %
# Epoch [14/50], Validation Loss: 0.6804, Validation Accuracy: 57.33 %
# Epoch [15/50], Validation Loss: 0.6759, Validation Accuracy: 59.00 %
# Epoch [16/50], Validation Loss: 0.6731, Validation Accuracy: 58.83 %
# Epoch [17/50], Validation Loss: 0.6727, Validation Accuracy: 58.83 %
# Epoch [18/50], Validation Loss: 0.6612, Validation Accuracy: 60.17 %
# Epoch [19/50], Validation Loss: 0.6635, Validation Accuracy: 59.83 %
# Epoch [20/50], Validation Loss: 0.6718, Validation Accuracy: 56.67 %
# Epoch [21/50], Validation Loss: 0.6654, Validation Accuracy: 58.67 %
# Epoch [22/50], Validation Loss: 0.6623, Validation Accuracy: 61.33 %
# Epoch [23/50], Validation Loss: 0.6601, Validation Accuracy: 58.83 %
# Epoch [24/50], Validation Loss: 0.6574, Validation Accuracy: 63.00 %
# Epoch [25/50], Validation Loss: 0.6861, Validation Accuracy: 57.83 %
# Epoch [26/50], Validation Loss: 0.6690, Validation Accuracy: 63.17 %
# Epoch [27/50], Validation Loss: 0.6661, Validation Accuracy: 58.17 %
# Epoch [28/50], Validation Loss: 0.6792, Validation Accuracy: 57.00 %
# Epoch [29/50], Validation Loss: 0.6600, Validation Accuracy: 61.17 %
# Epoch [30/50], Validation Loss: 0.6526, Validation Accuracy: 64.33 %
# Epoch [31/50], Validation Loss: 0.6461, Validation Accuracy: 62.67 %
# Epoch [32/50], Validation Loss: 0.6401, Validation Accuracy: 64.17 %
# Epoch [33/50], Validation Loss: 0.6393, Validation Accuracy: 66.67 %
# Epoch [34/50], Validation Loss: 0.6415, Validation Accuracy: 62.33 %
# Epoch [35/50], Validation Loss: 0.6476, Validation Accuracy: 64.00 %
# Epoch [36/50], Validation Loss: 0.6444, Validation Accuracy: 66.33 %
# Epoch [37/50], Validation Loss: 0.6509, Validation Accuracy: 63.00 %
# Epoch [38/50], Validation Loss: 0.6335, Validation Accuracy: 67.33 %
# Epoch [39/50], Validation Loss: 0.6531, Validation Accuracy: 64.50 %
# Epoch [40/50], Validation Loss: 0.6280, Validation Accuracy: 66.17 %
# Epoch [41/50], Validation Loss: 0.6320, Validation Accuracy: 68.00 %
# Epoch [42/50], Validation Loss: 0.6362, Validation Accuracy: 66.83 %
# Epoch [43/50], Validation Loss: 0.6379, Validation Accuracy: 64.50 %
# Epoch [44/50], Validation Loss: 0.6407, Validation Accuracy: 65.50 %
# Epoch [45/50], Validation Loss: 0.6754, Validation Accuracy: 67.50 %
# Epoch [46/50], Validation Loss: 0.6301, Validation Accuracy: 67.00 %
# Epoch [47/50], Validation Loss: 0.6298, Validation Accuracy: 65.17 %
# Epoch [48/50], Validation Loss: 0.6053, Validation Accuracy: 69.67 %
# Epoch [49/50], Validation Loss: 0.6377, Validation Accuracy: 67.83 %
# Epoch [50/50], Validation Loss: 0.6106, Validation Accuracy: 68.83 %
#
# Results saved for LeakyReLU - 64-64
#
# === Testing ELU - 64 with batch size 64 ===
# Epoch [1/50], Validation Loss: 0.6916, Validation Accuracy: 52.00 %
# Epoch [2/50], Validation Loss: 0.6848, Validation Accuracy: 58.33 %
# Epoch [3/50], Validation Loss: 0.6807, Validation Accuracy: 57.83 %
# Epoch [4/50], Validation Loss: 0.6963, Validation Accuracy: 53.33 %
# Epoch [5/50], Validation Loss: 0.6840, Validation Accuracy: 52.50 %
# Epoch [6/50], Validation Loss: 0.6758, Validation Accuracy: 56.17 %
# Epoch [7/50], Validation Loss: 0.6688, Validation Accuracy: 60.83 %
# Epoch [8/50], Validation Loss: 0.6592, Validation Accuracy: 62.00 %
# Epoch [9/50], Validation Loss: 0.6523, Validation Accuracy: 62.00 %
# Epoch [10/50], Validation Loss: 0.6475, Validation Accuracy: 62.50 %
# Epoch [11/50], Validation Loss: 0.6760, Validation Accuracy: 60.83 %
# Epoch [12/50], Validation Loss: 0.6409, Validation Accuracy: 66.33 %
# Epoch [13/50], Validation Loss: 0.6411, Validation Accuracy: 66.00 %
# Epoch [14/50], Validation Loss: 0.6541, Validation Accuracy: 63.83 %
# Epoch [15/50], Validation Loss: 0.6157, Validation Accuracy: 67.83 %
# Epoch [16/50], Validation Loss: 0.6294, Validation Accuracy: 64.67 %
# Epoch [17/50], Validation Loss: 0.6154, Validation Accuracy: 66.50 %
# Epoch [18/50], Validation Loss: 0.6047, Validation Accuracy: 68.33 %
# Epoch [19/50], Validation Loss: 0.6176, Validation Accuracy: 67.17 %
# Epoch [20/50], Validation Loss: 0.6275, Validation Accuracy: 65.67 %
# Epoch [21/50], Validation Loss: 0.5959, Validation Accuracy: 68.33 %
# Epoch [22/50], Validation Loss: 0.6143, Validation Accuracy: 67.83 %
# Epoch [23/50], Validation Loss: 0.5939, Validation Accuracy: 68.00 %
# Epoch [24/50], Validation Loss: 0.5858, Validation Accuracy: 70.00 %
# Epoch [25/50], Validation Loss: 0.6152, Validation Accuracy: 68.33 %
# Epoch [26/50], Validation Loss: 0.6071, Validation Accuracy: 68.67 %
# Epoch [27/50], Validation Loss: 0.6028, Validation Accuracy: 70.33 %
# Epoch [28/50], Validation Loss: 0.6044, Validation Accuracy: 69.67 %
# Epoch [29/50], Validation Loss: 0.6000, Validation Accuracy: 70.67 %
# Epoch [30/50], Validation Loss: 0.5739, Validation Accuracy: 71.33 %
# Epoch [31/50], Validation Loss: 0.5927, Validation Accuracy: 69.00 %
# Epoch [32/50], Validation Loss: 0.6045, Validation Accuracy: 70.50 %
# Epoch [33/50], Validation Loss: 0.5892, Validation Accuracy: 69.00 %
# Epoch [34/50], Validation Loss: 0.5879, Validation Accuracy: 70.00 %
# Epoch [35/50], Validation Loss: 0.6099, Validation Accuracy: 67.83 %
# Epoch [36/50], Validation Loss: 0.5970, Validation Accuracy: 70.33 %
# Epoch [37/50], Validation Loss: 0.5975, Validation Accuracy: 69.67 %
# Epoch [38/50], Validation Loss: 0.5926, Validation Accuracy: 71.83 %
# Epoch [39/50], Validation Loss: 0.5904, Validation Accuracy: 71.50 %
# Epoch [40/50], Validation Loss: 0.5971, Validation Accuracy: 70.83 %
# Epoch [41/50], Validation Loss: 0.6031, Validation Accuracy: 68.17 %
# Epoch [42/50], Validation Loss: 0.5688, Validation Accuracy: 72.50 %
# Epoch [43/50], Validation Loss: 0.5777, Validation Accuracy: 72.00 %
# Epoch [44/50], Validation Loss: 0.5671, Validation Accuracy: 71.33 %
# Epoch [45/50], Validation Loss: 0.5879, Validation Accuracy: 70.67 %
# Epoch [46/50], Validation Loss: 0.5672, Validation Accuracy: 73.33 %
# Epoch [47/50], Validation Loss: 0.5714, Validation Accuracy: 71.00 %
# Epoch [48/50], Validation Loss: 0.5670, Validation Accuracy: 71.33 %
# Epoch [49/50], Validation Loss: 0.5939, Validation Accuracy: 71.00 %
# Epoch [50/50], Validation Loss: 0.5721, Validation Accuracy: 72.00 %
#
# Results saved for ELU - 64-64
#
# === Testing ELU - 182 with batch size 128 ===
# Epoch [1/50], Validation Loss: 0.6949, Validation Accuracy: 48.83 %
# Epoch [2/50], Validation Loss: 0.6917, Validation Accuracy: 51.00 %
# Epoch [3/50], Validation Loss: 0.6844, Validation Accuracy: 55.17 %
# Epoch [4/50], Validation Loss: 0.6697, Validation Accuracy: 57.67 %
# Epoch [5/50], Validation Loss: 0.6737, Validation Accuracy: 60.67 %
# Epoch [6/50], Validation Loss: 0.6559, Validation Accuracy: 61.00 %
# Epoch [7/50], Validation Loss: 0.6489, Validation Accuracy: 62.33 %
# Epoch [8/50], Validation Loss: 0.6720, Validation Accuracy: 60.83 %
# Epoch [9/50], Validation Loss: 0.6605, Validation Accuracy: 62.00 %
# Epoch [10/50], Validation Loss: 0.6568, Validation Accuracy: 61.17 %
# Epoch [11/50], Validation Loss: 0.6538, Validation Accuracy: 63.00 %
# Epoch [12/50], Validation Loss: 0.6585, Validation Accuracy: 61.83 %
# Epoch [13/50], Validation Loss: 0.6573, Validation Accuracy: 61.83 %
# Epoch [14/50], Validation Loss: 0.6496, Validation Accuracy: 62.00 %
# Epoch [15/50], Validation Loss: 0.6643, Validation Accuracy: 60.00 %
# Epoch [16/50], Validation Loss: 0.6651, Validation Accuracy: 61.67 %
# Epoch [17/50], Validation Loss: 0.6371, Validation Accuracy: 64.00 %
# Epoch [18/50], Validation Loss: 0.6519, Validation Accuracy: 61.17 %
# Epoch [19/50], Validation Loss: 0.6340, Validation Accuracy: 63.50 %
# Epoch [20/50], Validation Loss: 0.6249, Validation Accuracy: 65.17 %
# Epoch [21/50], Validation Loss: 0.6439, Validation Accuracy: 63.83 %
# Epoch [22/50], Validation Loss: 0.6223, Validation Accuracy: 64.17 %
# Epoch [23/50], Validation Loss: 0.6263, Validation Accuracy: 65.50 %
# Epoch [24/50], Validation Loss: 0.6349, Validation Accuracy: 66.83 %
# Epoch [25/50], Validation Loss: 0.6449, Validation Accuracy: 64.50 %
# Epoch [26/50], Validation Loss: 0.6160, Validation Accuracy: 66.67 %
# Epoch [27/50], Validation Loss: 0.6303, Validation Accuracy: 65.00 %
# Epoch [28/50], Validation Loss: 0.6215, Validation Accuracy: 65.17 %
# Epoch [29/50], Validation Loss: 0.6112, Validation Accuracy: 65.33 %
# Epoch [30/50], Validation Loss: 0.6076, Validation Accuracy: 66.17 %
# Epoch [31/50], Validation Loss: 0.6060, Validation Accuracy: 67.83 %
# Epoch [32/50], Validation Loss: 0.6133, Validation Accuracy: 66.83 %
# Epoch [33/50], Validation Loss: 0.6122, Validation Accuracy: 66.33 %
# Epoch [34/50], Validation Loss: 0.6204, Validation Accuracy: 67.67 %
# Epoch [35/50], Validation Loss: 0.6199, Validation Accuracy: 66.17 %
# Epoch [36/50], Validation Loss: 0.6106, Validation Accuracy: 67.00 %
# Epoch [37/50], Validation Loss: 0.6150, Validation Accuracy: 65.50 %
# Epoch [38/50], Validation Loss: 0.6166, Validation Accuracy: 66.83 %
# Epoch [39/50], Validation Loss: 0.6203, Validation Accuracy: 66.67 %
# Epoch [40/50], Validation Loss: 0.6084, Validation Accuracy: 68.17 %
# Epoch [41/50], Validation Loss: 0.5987, Validation Accuracy: 68.50 %
# Epoch [42/50], Validation Loss: 0.6215, Validation Accuracy: 66.83 %
# Epoch [43/50], Validation Loss: 0.5999, Validation Accuracy: 68.17 %
# Epoch [44/50], Validation Loss: 0.5962, Validation Accuracy: 68.50 %
# Epoch [45/50], Validation Loss: 0.6437, Validation Accuracy: 64.83 %
# Epoch [46/50], Validation Loss: 0.6133, Validation Accuracy: 66.83 %
# Epoch [47/50], Validation Loss: 0.6079, Validation Accuracy: 65.83 %
# Epoch [48/50], Validation Loss: 0.6229, Validation Accuracy: 66.33 %
# Epoch [49/50], Validation Loss: 0.6065, Validation Accuracy: 69.00 %
# Epoch [50/50], Validation Loss: 0.5839, Validation Accuracy: 69.33 %
#
# Results saved for ELU - 182-128
#
# === Testing ELU - 256 with batch size 256 ===
# Epoch [1/50], Validation Loss: 0.6909, Validation Accuracy: 51.33 %
# Epoch [2/50], Validation Loss: 0.6836, Validation Accuracy: 54.83 %
# Epoch [3/50], Validation Loss: 0.6816, Validation Accuracy: 54.17 %
# Epoch [4/50], Validation Loss: 0.6748, Validation Accuracy: 56.67 %
# Epoch [5/50], Validation Loss: 0.6640, Validation Accuracy: 58.50 %
# Epoch [6/50], Validation Loss: 0.6677, Validation Accuracy: 60.83 %
# Epoch [7/50], Validation Loss: 0.6510, Validation Accuracy: 63.50 %
# Epoch [8/50], Validation Loss: 0.6534, Validation Accuracy: 64.50 %
# Epoch [9/50], Validation Loss: 0.6562, Validation Accuracy: 60.50 %
# Epoch [10/50], Validation Loss: 0.6428, Validation Accuracy: 64.67 %
# Epoch [11/50], Validation Loss: 0.6475, Validation Accuracy: 64.00 %
# Epoch [12/50], Validation Loss: 0.6501, Validation Accuracy: 63.17 %
# Epoch [13/50], Validation Loss: 0.6474, Validation Accuracy: 63.83 %
# Epoch [14/50], Validation Loss: 0.6425, Validation Accuracy: 64.00 %
# Epoch [15/50], Validation Loss: 0.6540, Validation Accuracy: 65.33 %
# Epoch [16/50], Validation Loss: 0.6488, Validation Accuracy: 64.17 %
# Epoch [17/50], Validation Loss: 0.6386, Validation Accuracy: 64.50 %
# Epoch [18/50], Validation Loss: 0.6303, Validation Accuracy: 66.33 %
# Epoch [19/50], Validation Loss: 0.6398, Validation Accuracy: 65.50 %
# Epoch [20/50], Validation Loss: 0.6291, Validation Accuracy: 66.00 %
# Epoch [21/50], Validation Loss: 0.6350, Validation Accuracy: 65.83 %
# Epoch [22/50], Validation Loss: 0.6433, Validation Accuracy: 65.17 %
# Epoch [23/50], Validation Loss: 0.6300, Validation Accuracy: 66.17 %
# Epoch [24/50], Validation Loss: 0.6197, Validation Accuracy: 66.50 %
# Epoch [25/50], Validation Loss: 0.6249, Validation Accuracy: 65.33 %
# Epoch [26/50], Validation Loss: 0.6294, Validation Accuracy: 66.50 %
# Epoch [27/50], Validation Loss: 0.6483, Validation Accuracy: 63.17 %
# Epoch [28/50], Validation Loss: 0.6394, Validation Accuracy: 63.50 %
# Epoch [29/50], Validation Loss: 0.6172, Validation Accuracy: 66.33 %
# Epoch [30/50], Validation Loss: 0.6133, Validation Accuracy: 66.67 %
# Epoch [31/50], Validation Loss: 0.6481, Validation Accuracy: 64.83 %
# Epoch [32/50], Validation Loss: 0.6140, Validation Accuracy: 67.33 %
# Epoch [33/50], Validation Loss: 0.6134, Validation Accuracy: 65.83 %
# Epoch [34/50], Validation Loss: 0.6155, Validation Accuracy: 67.67 %
# Epoch [35/50], Validation Loss: 0.6041, Validation Accuracy: 68.17 %
# Epoch [36/50], Validation Loss: 0.6034, Validation Accuracy: 69.00 %
# Epoch [37/50], Validation Loss: 0.6203, Validation Accuracy: 67.17 %
# Epoch [38/50], Validation Loss: 0.5964, Validation Accuracy: 68.17 %
# Epoch [39/50], Validation Loss: 0.6103, Validation Accuracy: 67.50 %
# Epoch [40/50], Validation Loss: 0.6142, Validation Accuracy: 66.50 %
# Epoch [41/50], Validation Loss: 0.6020, Validation Accuracy: 68.50 %
# Epoch [42/50], Validation Loss: 0.6338, Validation Accuracy: 65.83 %
# Epoch [43/50], Validation Loss: 0.5926, Validation Accuracy: 70.00 %
# Epoch [44/50], Validation Loss: 0.6064, Validation Accuracy: 67.83 %
# Epoch [45/50], Validation Loss: 0.5883, Validation Accuracy: 69.33 %
# Epoch [46/50], Validation Loss: 0.5907, Validation Accuracy: 68.83 %
# Epoch [47/50], Validation Loss: 0.5996, Validation Accuracy: 66.33 %
# Epoch [48/50], Validation Loss: 0.5968, Validation Accuracy: 69.67 %
# Epoch [49/50], Validation Loss: 0.6099, Validation Accuracy: 64.83 %
# Epoch [50/50], Validation Loss: 0.6085, Validation Accuracy: 69.17 %
#
# Results saved for ELU - 256-256
#
# === Testing SiLU - 64 with batch size 64 ===
# Epoch [1/50], Validation Loss: 0.6924, Validation Accuracy: 50.67 %
# Epoch [2/50], Validation Loss: 0.6835, Validation Accuracy: 59.33 %
# Epoch [3/50], Validation Loss: 0.7166, Validation Accuracy: 54.33 %
# Epoch [4/50], Validation Loss: 0.6770, Validation Accuracy: 56.67 %
# Epoch [5/50], Validation Loss: 0.6609, Validation Accuracy: 60.17 %
# Epoch [6/50], Validation Loss: 0.6708, Validation Accuracy: 58.83 %
# Epoch [7/50], Validation Loss: 0.6568, Validation Accuracy: 60.50 %
# Epoch [8/50], Validation Loss: 0.6512, Validation Accuracy: 63.00 %
# Epoch [9/50], Validation Loss: 0.6543, Validation Accuracy: 65.50 %
# Epoch [10/50], Validation Loss: 0.6387, Validation Accuracy: 64.17 %
# Epoch [11/50], Validation Loss: 0.6481, Validation Accuracy: 63.33 %
# Epoch [12/50], Validation Loss: 0.6443, Validation Accuracy: 64.17 %
# Epoch [13/50], Validation Loss: 0.6491, Validation Accuracy: 62.33 %
# Epoch [14/50], Validation Loss: 0.6633, Validation Accuracy: 60.33 %
# Epoch [15/50], Validation Loss: 0.6509, Validation Accuracy: 64.17 %
# Epoch [16/50], Validation Loss: 0.6212, Validation Accuracy: 65.00 %
# Epoch [17/50], Validation Loss: 0.6491, Validation Accuracy: 62.83 %
# Epoch [18/50], Validation Loss: 0.6391, Validation Accuracy: 63.67 %
# Epoch [19/50], Validation Loss: 0.6147, Validation Accuracy: 66.33 %
# Epoch [20/50], Validation Loss: 0.6445, Validation Accuracy: 63.50 %
# Epoch [21/50], Validation Loss: 0.6103, Validation Accuracy: 67.17 %
# Epoch [22/50], Validation Loss: 0.6120, Validation Accuracy: 66.00 %
# Epoch [23/50], Validation Loss: 0.6045, Validation Accuracy: 68.33 %
# Epoch [24/50], Validation Loss: 0.5936, Validation Accuracy: 69.50 %
# Epoch [25/50], Validation Loss: 0.6264, Validation Accuracy: 66.17 %
# Epoch [26/50], Validation Loss: 0.6070, Validation Accuracy: 67.00 %
# Epoch [27/50], Validation Loss: 0.5872, Validation Accuracy: 69.33 %
# Epoch [28/50], Validation Loss: 0.5870, Validation Accuracy: 68.17 %
# Epoch [29/50], Validation Loss: 0.5724, Validation Accuracy: 68.83 %
# Epoch [30/50], Validation Loss: 0.6294, Validation Accuracy: 66.50 %
# Epoch [31/50], Validation Loss: 0.5850, Validation Accuracy: 68.50 %
# Epoch [32/50], Validation Loss: 0.5735, Validation Accuracy: 70.33 %
# Epoch [33/50], Validation Loss: 0.5938, Validation Accuracy: 68.33 %
# Epoch [34/50], Validation Loss: 0.5732, Validation Accuracy: 70.33 %
# Epoch [35/50], Validation Loss: 0.5757, Validation Accuracy: 69.17 %
# Epoch [36/50], Validation Loss: 0.5727, Validation Accuracy: 69.67 %
# Epoch [37/50], Validation Loss: 0.6102, Validation Accuracy: 67.17 %
# Epoch [38/50], Validation Loss: 0.5645, Validation Accuracy: 71.33 %
# Epoch [39/50], Validation Loss: 0.5634, Validation Accuracy: 71.00 %
# Epoch [40/50], Validation Loss: 0.5691, Validation Accuracy: 70.50 %
# Epoch [41/50], Validation Loss: 0.5814, Validation Accuracy: 71.00 %
# Epoch [42/50], Validation Loss: 0.5561, Validation Accuracy: 71.33 %
# Epoch [43/50], Validation Loss: 0.5663, Validation Accuracy: 72.00 %
# Epoch [44/50], Validation Loss: 0.5724, Validation Accuracy: 70.67 %
# Epoch [45/50], Validation Loss: 0.5771, Validation Accuracy: 70.50 %
# Epoch [46/50], Validation Loss: 0.5686, Validation Accuracy: 71.17 %
# Epoch [47/50], Validation Loss: 0.5537, Validation Accuracy: 73.33 %
# Epoch [48/50], Validation Loss: 0.5487, Validation Accuracy: 73.83 %
# Epoch [49/50], Validation Loss: 0.5485, Validation Accuracy: 72.67 %
# Epoch [50/50], Validation Loss: 0.5652, Validation Accuracy: 70.50 %
#
# Results saved for SiLU - 64-64
#
# === Testing SiLU - 128 with batch size 128 ===
# Epoch [1/50], Validation Loss: 0.6926, Validation Accuracy: 49.83 %
# Epoch [2/50], Validation Loss: 0.6898, Validation Accuracy: 53.83 %
# Epoch [3/50], Validation Loss: 0.6893, Validation Accuracy: 52.50 %
# Epoch [4/50], Validation Loss: 0.6918, Validation Accuracy: 55.00 %
# Epoch [5/50], Validation Loss: 0.6788, Validation Accuracy: 55.83 %
# Epoch [6/50], Validation Loss: 0.6698, Validation Accuracy: 58.67 %
# Epoch [7/50], Validation Loss: 0.6700, Validation Accuracy: 59.33 %
# Epoch [8/50], Validation Loss: 0.6902, Validation Accuracy: 56.17 %
# Epoch [9/50], Validation Loss: 0.6620, Validation Accuracy: 59.33 %
# Epoch [10/50], Validation Loss: 0.6783, Validation Accuracy: 59.33 %
# Epoch [11/50], Validation Loss: 0.6607, Validation Accuracy: 57.67 %
# Epoch [12/50], Validation Loss: 0.6606, Validation Accuracy: 61.00 %
# Epoch [13/50], Validation Loss: 0.6671, Validation Accuracy: 61.00 %
# Epoch [14/50], Validation Loss: 0.6569, Validation Accuracy: 61.17 %
# Epoch [15/50], Validation Loss: 0.6580, Validation Accuracy: 61.17 %
# Epoch [16/50], Validation Loss: 0.6552, Validation Accuracy: 62.67 %
# Epoch [17/50], Validation Loss: 0.6731, Validation Accuracy: 58.50 %
# Epoch [18/50], Validation Loss: 0.6530, Validation Accuracy: 61.50 %
# Epoch [19/50], Validation Loss: 0.6536, Validation Accuracy: 63.83 %
# Epoch [20/50], Validation Loss: 0.6445, Validation Accuracy: 63.00 %
# Epoch [21/50], Validation Loss: 0.6529, Validation Accuracy: 61.50 %
# Epoch [22/50], Validation Loss: 0.6472, Validation Accuracy: 63.17 %
# Epoch [23/50], Validation Loss: 0.6565, Validation Accuracy: 60.33 %
# Epoch [24/50], Validation Loss: 0.6489, Validation Accuracy: 62.67 %
# Epoch [25/50], Validation Loss: 0.6396, Validation Accuracy: 63.50 %
# Epoch [26/50], Validation Loss: 0.6462, Validation Accuracy: 62.67 %
# Epoch [27/50], Validation Loss: 0.6517, Validation Accuracy: 63.17 %
# Epoch [28/50], Validation Loss: 0.6365, Validation Accuracy: 63.67 %
# Epoch [29/50], Validation Loss: 0.6260, Validation Accuracy: 65.00 %
# Epoch [30/50], Validation Loss: 0.6240, Validation Accuracy: 65.67 %
# Epoch [31/50], Validation Loss: 0.6332, Validation Accuracy: 64.33 %
# Epoch [32/50], Validation Loss: 0.6211, Validation Accuracy: 65.17 %
# Epoch [33/50], Validation Loss: 0.6307, Validation Accuracy: 64.50 %
# Epoch [34/50], Validation Loss: 0.6136, Validation Accuracy: 66.83 %
# Epoch [35/50], Validation Loss: 0.6170, Validation Accuracy: 67.17 %
# Epoch [36/50], Validation Loss: 0.6118, Validation Accuracy: 67.67 %
# Epoch [37/50], Validation Loss: 0.6010, Validation Accuracy: 67.50 %
# Epoch [38/50], Validation Loss: 0.6434, Validation Accuracy: 65.17 %
# Epoch [39/50], Validation Loss: 0.6157, Validation Accuracy: 67.33 %
# Epoch [40/50], Validation Loss: 0.6368, Validation Accuracy: 65.50 %
# Epoch [41/50], Validation Loss: 0.6212, Validation Accuracy: 67.00 %
# Epoch [42/50], Validation Loss: 0.6027, Validation Accuracy: 67.17 %
# Epoch [43/50], Validation Loss: 0.6071, Validation Accuracy: 68.17 %
# Epoch [44/50], Validation Loss: 0.6049, Validation Accuracy: 67.83 %
# Epoch [45/50], Validation Loss: 0.5890, Validation Accuracy: 67.00 %
# Epoch [46/50], Validation Loss: 0.5836, Validation Accuracy: 70.83 %
# Epoch [47/50], Validation Loss: 0.5737, Validation Accuracy: 71.33 %
# Epoch [48/50], Validation Loss: 0.5773, Validation Accuracy: 71.83 %
# Epoch [49/50], Validation Loss: 0.6080, Validation Accuracy: 67.17 %
# Epoch [50/50], Validation Loss: 0.5683, Validation Accuracy: 72.33 %
#
# Results saved for SiLU - 128-128
#
# All results saved

# %%
import matplotlib.pyplot as plt
import pickle
import pandas as pd

with open("select_cnn_experiments_ReLU - 128_128.pkl", "rb") as f:
    results = pickle.load(f)

df_relu_128 = pd.DataFrame(results)

with open("select_cnn_experiments_Tanh - 128_128.pkl", "rb") as f:
    results = pickle.load(f)

df_tanh_128 = pd.DataFrame(results)

with open("select_cnn_experiments_Tanh - 256_256.pkl", "rb") as f:
    results = pickle.load(f)

df_tanh_256 = pd.DataFrame(results)

with open("select_cnn_experiments_LeakyReLU - 64_64.pkl", "rb") as f:
    results = pickle.load(f)

df_leakyrelu_64 = pd.DataFrame(results)

with open("select_cnn_experiments_ELU - 64_64.pkl", "rb") as f:
    results = pickle.load(f)

df_elu_64 = pd.DataFrame(results)

with open("select_cnn_experiments_ELU - 128_128.pkl", "rb") as f:
    results = pickle.load(f)

df_elu_128 = pd.DataFrame(results)

with open("select_cnn_experiments_ELU - 256_256.pkl", "rb") as f:
    results = pickle.load(f)

df_elu_256 = pd.DataFrame(results)

with open("select_cnn_experiments_SiLU - 64_64.pkl", "rb") as f:
    results = pickle.load(f)

df_silu_64 = pd.DataFrame(results)

with open("select_cnn_experiments_SiLU - 128_128.pkl", "rb") as f:
    results = pickle.load(f)

df_silu_128 = pd.DataFrame(results)

dfs = [df_relu_128, df_tanh_128, df_tanh_256, df_leakyrelu_64, df_elu_64, df_elu_128, df_elu_256, df_silu_64, df_silu_128]

plt.figure()
for i, df in dfs.iterrows():
    label = f"AF = {row['activation_function']}, BS = {row['batch_size']}"
    plt.plot(row['val_accuracy_history'], label = label)
plt.title("Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 53
#      50 dfs = [df_relu_128, df_tanh_128, df_tanh_256, df_leakyrelu_64, df_elu_64, df_elu_128, df_elu_256, df_silu_64, df_silu_128]
#      52 plt.figure()
# ---> 53 for _, row in dfs.iterrows():
#      54     label = f"AF = {row['activation_function']}, BS = {row['batch_size']}"
#      55     plt.plot(row['val_accuracy_history'], label = label)
#
# AttributeError: 'list' object has no attribute 'iterrows'

# %%
import matplotlib.pyplot as plt
import pickle
import pandas as pd

with open("select_cnn_experiments.pkl", "rb") as f:
    all_results = pickle.load(f)

# Flatten if it's a list of lists
flat_results = []
for group in all_results:
    if isinstance(group, list):
        flat_results.extend(group)
    else:
        flat_results.append(group)

df_all = pd.DataFrame(flat_results)

plt.figure(figsize=(10, 6))

for _, row in df_all.iterrows():
    val_acc = row['val_accuracy_history']
    label = f"{row['activation_function']} - bs={row['batch_size']}"
    plt.plot(range(1, len(val_acc) + 1), val_acc, label=label)

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy (%)")
plt.title("Validation Accuracy Across All CNN Experiments")
plt.legend()
plt.show()
